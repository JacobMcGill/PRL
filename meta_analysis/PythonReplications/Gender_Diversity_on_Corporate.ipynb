# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df_director_expertise = pd.read_stata('director_expertise.dta')

# %%
#df_director_expertise.to_excel('test.xlsx')

# %%
df_director_expertise['tenure'] = df_director_expertise['year'] - df_director_expertise['dirsince']

# %%
expertise_list = ['financial_expert', 'merger_expert', 'accounting_expert', 'international_expert', 'operations_expert', 'technology_expert', 'marketing_expert', 'risk_management_expert', 'human_resources_expert', 'research_development_expert', 'sustainability_expert', 'corporate_governance_expert', 'regulatory_expert', 'political_expert', 'strategy_expert', 'leadership_expert']

# %%
# Define the formula for the probit model
#formula = "financial_expert ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + " + " + ".join(classification_dum.columns)
#formula = 'financial_expert ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + C(classification) + relative_yn + business_transaction + prof_services_yn + former_employee_yn + interlocking + designated + otherlink'

#formula = 'technology_expert ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + C(classification) + relative_yn + business_transaction + prof_services_yn + former_employee_yn + interlocking + designated + otherlink + charity'

#X_Vars = df_director_expertise[["female", "outside_public_boards", "age", "tenure", "num_of_shares", "employment_ceo", "employment_chairman", "employment_president", "employment_vicechairman", "employment_treasurer", "employment_cfo", "employment_coo", "employment_secretary", "employment_evp", "employment_svp", "employment_vp", "attend_less75_pct", "C(classification)", "relative_yn", "business_transaction", "prof_services_yn", "former_employee_yn", "interlocking", "designated", "otherlink"]]
#X_Vars = sm.add_constant(df_director_expertise[["female", "outside_public_boards", "age", "tenure", "num_of_shares", "employment_ceo", "employment_chairman", "employment_president", "employment_vicechairman", "employment_treasurer", "employment_cfo", "employment_coo", "employment_secretary", "employment_evp", "employment_svp", "employment_vp", "attend_less75_pct", "relative_yn", "business_transaction", "prof_services_yn", "former_employee_yn", "interlocking", "designated", "otherlink"]])

# Fit the probit model
#model = sm.Probit(df_director_expertise['merger_expert'],X_Vars, data=df_director_expertise)
#link_function = sm.families.links.probit()
#model = smf.glm(formula=formula,data=df_director_expertise,family=sm.families.Binomial(link=sm.families.links.probit()))
#model = smf.probit(formula=formula,data=df_director_expertise)
#model = sm.GLM()
#result = model.fit()

model_list = list()

for i in expertise_list:
    try:
        model = smf.probit(formula = i + ' ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + C(classification) + relative_yn + business_transaction + prof_services_yn + former_employee_yn + interlocking + designated + otherlink + charity',data=df_director_expertise).fit()
    except:
        try:
            model = smf.probit(formula = i + ' ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + C(classification) + relative_yn + business_transaction + prof_services_yn + former_employee_yn + interlocking + designated + otherlink',data=df_director_expertise).fit()
        except:
            model = smf.glm(formula= i + ' ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + C(classification) + relative_yn + business_transaction + prof_services_yn + former_employee_yn + interlocking + designated + otherlink + charity', data=df_director_expertise,family=sm.families.Binomial(link=sm.families.links.probit())).fit()
    model_list.append(model)

# Display the summary
#print(result.summary())
# Out:
# ...
#          Current function value: 0.664340
#          Iterations: 35
# ...
#          Current function value: 0.664340
#          Iterations: 35
# c:\Users\wills\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...
#          Current function value: 0.558257
#          Iterations: 35
# ...
#          Current function value: 0.558257
#          Iterations: 35
# c:\Users\wills\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.632688
#          Iterations 20
# Optimization terminated successfully.
#          Current function value: 0.632688
#          Iterations 27
# ...
#          Current function value: 0.606615
# ...

# %%
for i in model_list:
    print(i.summary())
# Out:
#                           Probit Regression Results
# ...
# Dep. Variable:       financial_expert   No. Observations:                 4859
# Model:                         Probit   Df Residuals:                     4832
# Method:                           MLE   Df Model:                           26
# Date:                Thu, 21 Dec 2023   Pseudo R-squ.:                 0.02887
# Time:                        03:55:09   Log-Likelihood:                -3228.0
# converged:                      False   LL-Null:                       -3324.0
# Covariance Type:            nonrobust   LLR p-value:                 3.062e-27
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.3890        nan        nan        nan         nan         nan
# C(classification)[T.E]      0.1744        nan        nan        nan         nan         nan
# ...

# %%
for i in expertise_list:
    model = smf.glm(formula= i + ' ~ female + outside_public_boards + age + tenure + num_of_shares + employment_ceo + employment_chairman + employment_president + employment_vicechairman + employment_treasurer + employment_cfo + employment_coo + employment_secretary + employment_evp + employment_svp + employment_vp + attend_less75_pct + C(classification) + relative_yn + business_transaction + prof_services_yn + former_employee_yn + interlocking + designated + otherlink + charity', data=df_director_expertise,family=sm.families.Binomial(link=sm.families.links.probit())).fit()
    print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:       financial_expert   No. Observations:                 4859
# Model:                            GLM   Df Residuals:                     4832
# Model Family:                Binomial   Df Model:                           26
# Link Function:                 probit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -3228.0
# Date:                Thu, 21 Dec 2023   Deviance:                       6456.1
# Time:                        03:55:10   Pearson chi2:                 4.81e+03
# No. Iterations:                    24   Pseudo R-squ. (CS):            0.03873
# Covariance Type:            nonrobust
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...
