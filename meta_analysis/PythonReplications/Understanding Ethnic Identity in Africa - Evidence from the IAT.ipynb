# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
data_paths = [
    "Lowes_Nunn_Robinson_Weigel_AERPP_2015.dta"
]

# %%
df = [pd.read_stata(path) for path in data_paths]
df = pd.concat(df)
# df.set_index('ID', inplace=True)
df
# Out:
#          ID target_group       IAT closeness  perception  same_ethnicity  \
# 0       1.0        bindi       NaN       NaN         NaN             NaN
# 1       1.0         kete       NaN       NaN         NaN             NaN
# 2       1.0         kuba -0.374016       3.0         2.0             1.0
# 3       1.0         lele -0.051109       3.0         2.0             0.0
# 4       1.0         luba  0.041002       3.0         2.0             0.0
# ...     ...          ...       ...       ...         ...             ...
# 3439  696.0         kete       NaN       NaN         NaN             NaN
# 3440  696.0         kuba  0.062701       3.0         3.0             0.0
# 3441  696.0         lele  0.337559       4.0         3.0             1.0
# 3442  696.0         luba  0.229391       2.0         3.0             0.0
# 3443  696.0       luluwa -0.112187       2.0         3.0             0.0
#
#       enum_same_ethnicity  order
# 0                     NaN    0.0
# ...

# %%
# Delete observations with missing data 
# keep if missing(IAT)!=1 & missing(closeness)!=1 & missing(perception)!=1
df = df[ (df['IAT'].notnull()) & (df['closeness'].notnull()) & (df['perception'].notnull()) ]

# %%
# closeness variable contains string variables 

# convert 'Closest together' to 5.0
df['closeness'] = df['closeness'].replace('Closest together', 5)

# convert 'Farthest apart' to 0.0
df['closeness'] = df['closeness'].replace('Farthest apart', 0)

# Convert 'closeness' variable from category type to int type
df['closeness'] = df['closeness'].cat.codes.astype(int)
# Out:
# C:\Users\wills\AppData\Local\Temp\ipykernel_30628\915228289.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['closeness'] = df['closeness'].replace('Closest together', 5)
# C:\Users\wills\AppData\Local\Temp\ipykernel_30628\915228289.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['closeness'] = df['closeness'].replace('Farthest apart', 0)
# C:\Users\wills\AppData\Local\Temp\ipykernel_30628\915228289.py:10: SettingWithCopyWarning:
# ...

# %%
# Define and fit the fixed-effects regression model for feeling of closeness (col 1)

model = smf.ols("closeness ~ same_ethnicity + C(target_group) + C(ID)", df)
result = model.fit()

# Print the summary of the regression results
print(result.summary())

# 0.942 matches
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              closeness   R-squared:                       0.524
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     3.256
# Date:                Fri, 24 May 2024   Prob (F-statistic):           3.45e-73
# Time:                        02:26:56   Log-Likelihood:                -2731.6
# No. Observations:                2133   AIC:                             6543.
# Df Residuals:                    1593   BIC:                             9602.
# Df Model:                         539
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     2.6819      0.505      5.306      0.000       1.690       3.673
# ...

# %%
# Define and fit the fixed-effects regression model for positivity of perception (col 2)

model = smf.ols("perception ~ same_ethnicity + C(target_group) + C(ID)", df)
result = model.fit()

# Print the summary of the regression results
print(result.summary())

# 0.597 matches
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             perception   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     2.596
# Date:                Fri, 24 May 2024   Prob (F-statistic):           1.30e-47
# Time:                        02:26:57   Log-Likelihood:                -2441.3
# No. Observations:                2133   AIC:                             5963.
# Df Residuals:                    1593   BIC:                             9022.
# Df Model:                         539
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     1.7765      0.441      4.027      0.000       0.911       2.642
# ...

# %%
# Define and fit the fixed-effects regression model for ST ethnicity IAT D-score (col 3)

model = smf.ols("IAT ~ same_ethnicity + C(target_group) + C(ID)", df)
result = model.fit()

# Print the summary of the regression results
print(result.summary())

# 0.062 matches
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    IAT   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.180
# Date:                Fri, 24 May 2024   Prob (F-statistic):            0.00853
# Time:                        02:26:58   Log-Likelihood:                -894.93
# No. Observations:                2133   AIC:                             2870.
# Df Residuals:                    1593   BIC:                             5929.
# Df Model:                         539
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.0484      0.214     -0.227      0.821      -0.468       0.371
# ...

# %%
# Define and fit the fixed-effects regression model for feeling of closeness (col 4)

model = smf.ols("closeness ~ same_ethnicity + enum_same_ethnicity + C(target_group) + C(ID)", df)
result = model.fit()

# Print the summary of the regression results
print(result.summary())

# 0.951 matches
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              closeness   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     3.266
# Date:                Fri, 24 May 2024   Prob (F-statistic):           1.18e-73
# Time:                        02:26:59   Log-Likelihood:                -2728.4
# No. Observations:                2133   AIC:                             6539.
# Df Residuals:                    1592   BIC:                             9604.
# Df Model:                         540
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     2.6728      0.505      5.294      0.000       1.682       3.663
# ...

# %%
# Define and fit the fixed-effects regression model for Perception (col 5)

model = smf.ols("perception ~ same_ethnicity + enum_same_ethnicity + C(target_group) + C(ID)", df)
result = model.fit()

# Print the summary of the regression results
print(result.summary())


# 0.0606 matches
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             perception   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     2.613
# Date:                Fri, 24 May 2024   Prob (F-statistic):           2.63e-48
# Time:                        02:27:00   Log-Likelihood:                -2436.8
# No. Observations:                2133   AIC:                             5956.
# Df Residuals:                    1592   BIC:                             9021.
# Df Model:                         540
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     1.7670      0.440      4.012      0.000       0.903       2.631
# ...

# %%
# Define and fit the fixed-effects regression model for ST ethnicity IAT D-score (col 6)

model = smf.ols("IAT ~ same_ethnicity + enum_same_ethnicity + C(target_group) + C(ID)", df)
result = model.fit()

# Print the summary of the regression results
print(result.summary())

# 0.061 matches
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    IAT   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.177
# Date:                Fri, 24 May 2024   Prob (F-statistic):            0.00931
# Time:                        02:27:01   Log-Likelihood:                -894.87
# No. Observations:                2133   AIC:                             2872.
# Df Residuals:                    1592   BIC:                             5937.
# Df Model:                         540
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.0479      0.214     -0.224      0.823      -0.467       0.371
# ...
