# %% [markdown]
# # Table 1
#
# `pip install pandas statsmodels linearmodels`

# %%
import pandas as pd
from linearmodels.panel import PanelOLS

df = pd.read_stata('dataset_for_aer_pnp.dta')

df = df.set_index(['fips', 'year'])

independent_vars_black = ['b_urban', 'b_highschoolgrad', 'b_femalehead', 'b_age', 'b_agesq']
independent_vars_white = ['w_urban', 'w_highschoolgrad', 'w_femalehead', 'w_age', 'w_agesq']
independent_vars_gap = ['black_white_urban', 'black_white_highschool', 'black_white_female', 'black_white_mean_age', 'black_white_mean_agesq']

df['constant'] = 1

# Run panel regression
def run_regression(dependent_var, independent_vars, data):
    independent_vars_with_free = independent_vars + ['free', 'constant']
    model = PanelOLS(data[dependent_var], data[independent_vars_with_free], entity_effects=True, time_effects=True)
    results = model.fit(cov_type='clustered', cluster_entity=True)
    print(results.summary)

# Filter out states with low black populations
def filter_low_black_population(data):
    return data[data['lowblack2pct'] != 1]

# Run the regressions for all states (columns 1, 2, and 3)
print("Running regressions for all states")
run_regression('ln_realb_medianhhincome', independent_vars_black, df)
run_regression('ln_realw_medianhhincome', independent_vars_white, df)
run_regression('ln_gap', independent_vars_gap, df)

# Run the regressions excluding states with low black populations (columns 4, 5, and 6)
df_filtered = filter_low_black_population(df)
print("Running regressions excluding low black population states")
run_regression('ln_realb_medianhhincome', independent_vars_black, df_filtered)
run_regression('ln_realw_medianhhincome', independent_vars_white, df_filtered)
run_regression('ln_gap', independent_vars_gap, df_filtered)
# Out:
# Running regressions for all states
#                              PanelOLS Estimation Summary
# =====================================================================================
# Dep. Variable:     ln_realb_medianhhincome   R-squared:                        0.0622
# Estimator:                        PanelOLS   R-squared (Between):             -0.1317
# No. Observations:                      200   R-squared (Within):              -0.1236
# Date:                     Fri, May 24 2024   R-squared (Overall):             -0.1289
# Time:                             13:46:56   Log-likelihood                    158.86
# Cov. Estimator:                  Clustered
#                                              F-statistic:                      1.5585
# Entities:                               50   P-value                           0.1636
# Avg Obs:                            4.0000   Distribution:                   F(6,141)
# Min Obs:                            4.0000
# Max Obs:                            4.0000   F-statistic (robust):             0.6271
#                                              P-value                           0.7084
# Time periods:                            4   Distribution:                   F(6,141)
# Avg Obs:                            50.000
# Min Obs:                            50.000
# Max Obs:                            50.000
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# b_urban              0.0420     0.2233     0.1883     0.8509     -0.3993      0.4834
# b_highschoolgrad    -0.3118     0.5246    -0.5943     0.5533     -1.3488      0.7253
# b_femalehead        -0.5649     0.5823    -0.9702     0.3336     -1.7160      0.5862
# b_age               -0.1060     0.2082    -0.5091     0.6115     -0.5176      0.3056
# b_agesq              0.0015     0.0025     0.6012     0.5487     -0.0035      0.0065
# free                 0.0116     0.0317     0.3653     0.7154     -0.0511      0.0743
# constant             7.2991     4.7402     1.5398     0.1258     -2.0719      16.670
# ====================================================================================
#
# F-test for Poolability: 5.1485
# P-value: 0.0000
# Distribution: F(52,141)
#
# Included effects: Entity, Time
#                              PanelOLS Estimation Summary
# =====================================================================================
# Dep. Variable:     ln_realw_medianhhincome   R-squared:                        0.4139
# Estimator:                        PanelOLS   R-squared (Between):              0.1492
# No. Observations:                      200   R-squared (Within):              -0.2370
# Date:                     Fri, May 24 2024   R-squared (Overall):              0.0494
# Time:                             13:46:56   Log-likelihood                    371.41
# Cov. Estimator:                  Clustered
#                                              F-statistic:                      16.595
# Entities:                               50   P-value                           0.0000
# Avg Obs:                            4.0000   Distribution:                   F(6,141)
# Min Obs:                            4.0000
# Max Obs:                            4.0000   F-statistic (robust):             14.227
#                                              P-value                           0.0000
# Time periods:                            4   Distribution:                   F(6,141)
# Avg Obs:                            50.000
# Min Obs:                            50.000
# Max Obs:                            50.000
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# w_urban              0.0712     0.1035     0.6874     0.4929     -0.1335      0.2759
# w_highschoolgrad     0.1745     0.2222     0.7854     0.4335     -0.2648      0.6139
# w_femalehead        -3.0895     0.8281    -3.7310     0.0003     -4.7265     -1.4525
# w_age                0.0457     0.0608     0.7513     0.4538     -0.0746      0.1660
# w_agesq             -0.0006     0.0007    -0.9182     0.3601     -0.0020      0.0007
# free                 0.0848     0.0141     5.9988     0.0000      0.0568      0.1127
# constant             4.3338     1.5144     2.8617     0.0049      1.3399      7.3276
# ====================================================================================
#
# F-test for Poolability: 21.166
# P-value: 0.0000
# Distribution: F(52,141)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 ln_gap   R-squared:                        0.2193
# Estimator:                   PanelOLS   R-squared (Between):             -1.2226
# No. Observations:                 186   R-squared (Within):              -0.2144
# Date:                Fri, May 24 2024   R-squared (Overall):             -0.4768
# Time:                        13:46:56   Log-likelihood                    525.51
# Cov. Estimator:             Clustered
#                                         F-statistic:                      6.0403
# Entities:                          48   P-value                           0.0000
# Avg Obs:                       3.8750   Distribution:                   F(6,129)
# Min Obs:                       2.0000
# Max Obs:                       4.0000   F-statistic (robust):             2.6274
#                                         P-value                           0.0195
# Time periods:                       4   Distribution:                   F(6,129)
# Avg Obs:                       46.500
# Min Obs:                       45.000
# Max Obs:                       47.000
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# black_white_urban          0.0328     0.0177     1.8542     0.0660     -0.0022      0.0678
# black_white_highschool     0.0863     0.0470     1.8336     0.0690     -0.0068      0.1794
# black_white_female        -0.0040     0.0085    -0.4705     0.6388     -0.0209      0.0129
# black_white_mean_age      -3.2888     2.3020    -1.4287     0.1555     -7.8433      1.2658
# black_white_mean_agesq     1.9368     1.3022     1.4874     0.1394     -0.6396      4.5132
# free                      -0.0197     0.0061    -3.2439     0.0015     -0.0318     -0.0077
# constant                   2.3397     1.0105     2.3155     0.0222      0.3405      4.3390
# ==========================================================================================
#
# F-test for Poolability: 3.6704
# P-value: 0.0000
# Distribution: F(50,129)
#
# Included effects: Entity, Time
# Running regressions excluding low black population states
#                              PanelOLS Estimation Summary
# =====================================================================================
# Dep. Variable:     ln_realb_medianhhincome   R-squared:                        0.2106
# Estimator:                        PanelOLS   R-squared (Between):              0.5312
# No. Observations:                      156   R-squared (Within):              -0.1597
# Date:                     Fri, May 24 2024   R-squared (Overall):              0.3448
# Time:                             13:46:56   Log-likelihood                    180.04
# Cov. Estimator:                  Clustered
#                                              F-statistic:                      4.8033
# Entities:                               39   P-value                           0.0002
# Avg Obs:                            4.0000   Distribution:                   F(6,108)
# Min Obs:                            4.0000
# Max Obs:                            4.0000   F-statistic (robust):             4.2384
#                                              P-value                           0.0007
# Time periods:                            4   Distribution:                   F(6,108)
# Avg Obs:                            39.000
# Min Obs:                            39.000
# Max Obs:                            39.000
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# b_urban              0.4626     0.3095     1.4944     0.1380     -0.1510      1.0762
# b_highschoolgrad     1.2213     0.6006     2.0333     0.0445      0.0307      2.4119
# b_femalehead        -0.9824     0.6389    -1.5376     0.1271     -2.2488      0.2840
# b_age                0.2832     0.2491     1.1372     0.2580     -0.2105      0.7769
# b_agesq             -0.0033     0.0030    -1.1081     0.2703     -0.0093      0.0026
# free                 0.0261     0.0347     0.7514     0.4540     -0.0427      0.0948
# constant            -1.9175     5.4010    -0.3550     0.7233     -12.623      8.7882
# ====================================================================================
#
# F-test for Poolability: 7.8815
# P-value: 0.0000
# Distribution: F(41,108)
#
# Included effects: Entity, Time
#                              PanelOLS Estimation Summary
# =====================================================================================
# Dep. Variable:     ln_realw_medianhhincome   R-squared:                        0.3553
# Estimator:                        PanelOLS   R-squared (Between):              0.3491
# No. Observations:                      156   R-squared (Within):              -0.3912
# Date:                     Fri, May 24 2024   R-squared (Overall):              0.1804
# Time:                             13:46:56   Log-likelihood                    299.72
# Cov. Estimator:                  Clustered
#                                              F-statistic:                      9.9201
# Entities:                               39   P-value                           0.0000
# Avg Obs:                            4.0000   Distribution:                   F(6,108)
# Min Obs:                            4.0000
# Max Obs:                            4.0000   F-statistic (robust):             9.8200
#                                              P-value                           0.0000
# Time periods:                            4   Distribution:                   F(6,108)
# Avg Obs:                            39.000
# Min Obs:                            39.000
# Max Obs:                            39.000
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# w_urban              0.2270     0.1154     1.9676     0.0517     -0.0017      0.4557
# w_highschoolgrad     0.1631     0.2297     0.7101     0.4791     -0.2922      0.6185
# w_femalehead        -2.0532     0.8996    -2.2822     0.0244     -3.8364     -0.2699
# w_age                0.0844     0.0738     1.1427     0.2557     -0.0620      0.2307
# w_agesq             -0.0012     0.0009    -1.3127     0.1921     -0.0030      0.0006
# free                 0.0763     0.0172     4.4404     0.0000      0.0422      0.1104
# constant             3.6392     1.6974     2.1440     0.0343      0.2746      7.0037
# ====================================================================================
#
# F-test for Poolability: 23.280
# P-value: 0.0000
# Distribution: F(41,108)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 ln_gap   R-squared:                        0.4012
# Estimator:                   PanelOLS   R-squared (Between):             -0.6171
# No. Observations:                 154   R-squared (Within):              -0.0171
# Date:                Fri, May 24 2024   R-squared (Overall):             -0.3022
# Time:                        13:46:56   Log-likelihood                    494.42
# Cov. Estimator:             Clustered
#                                         F-statistic:                      11.838
# Entities:                          39   P-value                           0.0000
# Avg Obs:                       3.9487   Distribution:                   F(6,106)
# Min Obs:                       2.0000
# Max Obs:                       4.0000   F-statistic (robust):             6.7300
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                   F(6,106)
# Avg Obs:                       38.500
# Min Obs:                       38.000
# Max Obs:                       39.000
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# black_white_urban          0.0356     0.0123     2.9006     0.0045      0.0113      0.0599
# black_white_highschool     0.1762     0.0540     3.2642     0.0015      0.0692      0.2832
# black_white_female        -0.0046     0.0072    -0.6455     0.5200     -0.0189      0.0096
# black_white_mean_age       0.4633     2.9441     0.1574     0.8753     -5.3736      6.3002
# black_white_mean_agesq    -0.2177     1.6181    -0.1345     0.8932     -3.4257      2.9903
# free                      -0.0141     0.0070    -2.0136     0.0466     -0.0279     -0.0002
# constant                   0.5936     1.3326     0.4454     0.6569     -2.0484      3.2356
# ==========================================================================================
#
# F-test for Poolability: 5.8303
# P-value: 0.0000
# Distribution: F(41,106)
#
# Included effects: Entity, Time
# /Users/isadavrod/anaconda3/lib/python3.11/site-packages/linearmodels/panel/model.py:1219: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/isadavrod/anaconda3/lib/python3.11/site-packages/linearmodels/panel/model.py:1219: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
